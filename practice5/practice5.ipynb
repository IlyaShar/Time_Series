# %%
from matplotlib import pyplot as plt
import pandas as pd
import numpy as np
import plotly.express as px
from sklearn.metrics import mean_absolute_percentage_error, mean_absolute_error, mean_squared_error, r2_score
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from numpy import asarray

# %%
# аналогичным образом загружаем данные о пассажирах
passengers = pd.read_csv('data/passengers.csv')
# неподходящий формат данных приводим к тому, с которым Pandas может работать
passengers['Month'] = pd.to_datetime(passengers['Month'])
# также устанавливаем индекс и сортируем
df = passengers.set_index('Month').sort_index()

# %%
df
# Out:
#             Passengers
# Month
# 1949-01-01         112
# 1949-02-01         118
# 1949-03-01         132
# 1949-04-01         129
# 1949-05-01         121
# ...                ...
# 1960-08-01         606
# 1960-09-01         508
# 1960-10-01         461
# 1960-11-01         390
# 1960-12-01         432
#
# [144 rows x 1 columns]

# %% [markdown]
# ## Предсказание временного ряда с помощью деревьев

# %% [markdown]
# Попробуем обычное дерево решений и случайный лес, а потом сравним результаты

# %%
cols = []
for i in range(1, 0, -1):
    cols.append(df.shift(i))
cols
# Out:
# [            Passengers
#  Month
#  1949-01-01         NaN
#  1949-02-01       112.0
#  1949-03-01       118.0
#  1949-04-01       132.0
#  1949-05-01       129.0
#  ...                ...
#  1960-08-01       622.0
#  1960-09-01       606.0
#  1960-10-01       508.0
#  1960-11-01       461.0
#  1960-12-01       390.0
#
#  [144 rows x 1 columns]]

# %%
cols = []
for i in range(1, 0, -1):
    cols.append(df.shift(i))
for i in range(0, 1):
    cols.append(df.shift(-i))
cols
# Out:
# [            Passengers
#  Month
#  1949-01-01         NaN
#  1949-02-01       112.0
#  1949-03-01       118.0
#  1949-04-01       132.0
#  1949-05-01       129.0
#  ...                ...
#  1960-08-01       622.0
#  1960-09-01       606.0
#  1960-10-01       508.0
#  1960-11-01       461.0
#  1960-12-01       390.0
#
#  [144 rows x 1 columns],
#              Passengers
#  Month
#  1949-01-01         112
#  1949-02-01         118
#  1949-03-01         132
#  1949-04-01         129
#  1949-05-01         121
#  ...                ...
#  1960-08-01         606
#  1960-09-01         508
#  1960-10-01         461
#  1960-11-01         390
#  1960-12-01         432
#
#  [144 rows x 1 columns]]

# %%
agg = pd.concat(cols, axis=1)
agg.dropna(inplace=True)
agg
# Out:
#             Passengers  Passengers
# Month
# 1949-02-01       112.0         118
# 1949-03-01       118.0         132
# 1949-04-01       132.0         129
# 1949-05-01       129.0         121
# 1949-06-01       121.0         135
# ...                ...         ...
# 1960-08-01       622.0         606
# 1960-09-01       606.0         508
# 1960-10-01       508.0         461
# 1960-11-01       461.0         390
# 1960-12-01       390.0         432
#
# [143 rows x 2 columns]

# %%
n_vars = 1 if type(df) is list else df.shape[1]
cols = []
for i in range(1, 0, -1):
    cols.append(df.shift(i))
for i in range(0, 1):
    cols.append(df.shift(-i))
# put it all together
agg = pd.concat(cols, axis=1)
agg.dropna(inplace=True)
list_for_forecast = agg.values

# %%
len(list_for_forecast)
# Out:
# 143

# %%
def decision_tree_forecast(train, testX):
    train = asarray(train)
    trainX, trainy = train[:, :-1], train[:, -1]
    model = DecisionTreeRegressor(random_state=0)
    model.fit(trainX, trainy)
    yhat = model.predict([testX])
    return yhat[0]

# %%
def random_forest_forecast(train, testX):
    train = asarray(train)
    trainX, trainy = train[:, :-1], train[:, -1]
    model = RandomForestRegressor(n_estimators=1000)
    model.fit(trainX, trainy)
    yhat = model.predict([testX])
    return yhat[0]

# %%
predictions = []
size = int(len(list_for_forecast) * 0.66)
train, test = list_for_forecast[0:size], list_for_forecast[size:len(list_for_forecast)]
history = [x for x in train]
history
# Out:
# [array([112., 118.]),
#  array([118., 132.]),
#  array([132., 129.]),
#  array([129., 121.]),
#  array([121., 135.]),
#  array([135., 148.]),
#  array([148., 148.]),
#  array([148., 136.]),
#  array([136., 119.]),
#  array([119., 104.]),
#  array([104., 118.]),
#  array([118., 115.]),
#  array([115., 126.]),
#  array([126., 141.]),
#  array([141., 135.]),
#  array([135., 125.]),
#  array([125., 149.]),
#  array([149., 170.]),
#  array([170., 170.]),
#  array([170., 158.]),
#  array([158., 133.]),
#  array([133., 114.]),
#  array([114., 140.]),
#  array([140., 145.]),
#  array([145., 150.]),
#  array([150., 178.]),
#  array([178., 163.]),
#  array([163., 172.]),
#  array([172., 178.]),
#  array([178., 199.]),
#  array([199., 199.]),
#  array([199., 184.]),
#  array([184., 162.]),
#  array([162., 146.]),
#  array([146., 166.]),
#  array([166., 171.]),
#  array([171., 180.]),
#  array([180., 193.]),
#  array([193., 181.]),
#  array([181., 183.]),
#  array([183., 218.]),
#  array([218., 230.]),
#  array([230., 242.]),
#  array([242., 209.]),
#  array([209., 191.]),
#  array([191., 172.]),
#  array([172., 194.]),
#  array([194., 196.]),
#  array([196., 196.]),
#  array([196., 236.]),
#  array([236., 235.]),
#  array([235., 229.]),
#  array([229., 243.]),
#  array([243., 264.]),
#  array([264., 272.]),
#  array([272., 237.]),
#  array([237., 211.]),
#  array([211., 180.]),
#  array([180., 201.]),
#  array([201., 204.]),
#  array([204., 188.]),
#  array([188., 235.]),
#  array([235., 227.]),
#  array([227., 234.]),
#  array([234., 264.]),
#  array([264., 302.]),
#  array([302., 293.]),
#  array([293., 259.]),
#  array([259., 229.]),
#  array([229., 203.]),
#  array([203., 229.]),
#  array([229., 242.]),
#  array([242., 233.]),
#  array([233., 267.]),
#  array([267., 269.]),
#  array([269., 270.]),
#  array([270., 315.]),
#  array([315., 364.]),
#  array([364., 347.]),
#  array([347., 312.]),
#  array([312., 274.]),
#  array([274., 237.]),
#  array([237., 278.]),
#  array([278., 284.]),
#  array([284., 277.]),
#  array([277., 317.]),
#  array([317., 313.]),
#  array([313., 318.]),
#  array([318., 374.]),
#  array([374., 413.]),
#  array([413., 405.]),
#  array([405., 355.]),
#  array([355., 306.]),
#  array([306., 271.])]

# %%
train.dtype(list())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 train.dtype(list())
#
# TypeError: 'numpy.dtypes.Float64DType' object is not callable

# %%
predictions = []
size = int(len(list_for_forecast) * 0.66)
train, test = list_for_forecast[0:size], list_for_forecast[size:len(list_for_forecast)]
history = [x for x in train]

for i in range(len(test)):
    testX, testy = test[i, :-1], test[i, -1]
    yhat = random_forest_forecast(history, testX)
    predictions.append(yhat)
    history.append(test[i])

error = mean_absolute_error(test[:, -1], predictions)
print("Random Forest error: ", error)
# Out:
# Random Forest error:  46.76690559604794

# %%
print("Random Forest metrics: ")
print("RMSE:", np.sqrt(mean_squared_error(test[:, -1], predictions)))
print("MAPE:", mean_absolute_percentage_error(test[:, -1], predictions))
print("MAE:", mean_absolute_error(test[:, -1], predictions))
print("R2: ", r2_score(test[:, -1], predictions))
# Out:
# Random Forest metrics:
# RMSE: 55.605787928438396
# MAPE: 0.10989509638510839
# MAE: 46.76690559604794
# R2:  0.49653348318219914

# %%
fig = plt.figure(figsize=(20, 9))
plt.plot(test[:, -1], label='Original data')
plt.plot(predictions, label='Random Forest')
plt.legend(fontsize="20")
plt.title('Airline passengers by month')
plt.ylabel('Total passengers', fontsize="20")
plt.xlabel('Month', fontsize="20")
plt.show()

# %%
predictions = list()
size = int(len(list_for_forecast) * 0.66)
train, test = list_for_forecast[0:size], list_for_forecast[size:len(list_for_forecast)]
history = [x for x in train]

for i in range(len(test)):
    testX, testy = test[i, :-1], test[i, -1]
    yhat = decision_tree_forecast(history, testX)
    predictions.append(yhat)
    history.append(test[i])

# %%
print("Decision Forest metrics: ")
print("RMSE:", np.sqrt(mean_squared_error(test[:, -1], predictions)))
print("MAPE:", mean_absolute_percentage_error(test[:, -1], predictions))
print("MAE:", mean_absolute_error(test[:, -1], predictions))
print("R2: ", r2_score(test[:, -1], predictions))
# Out:
# Decision Forest metrics:
# RMSE: 65.29403666867132
# MAPE: 0.12270617535711836
# MAE: 52.1530612244898
# R2:  0.3058111520951716

# %%
fig = plt.figure(figsize=(20, 9))
plt.plot(test[:, -1], label='Original data')
plt.plot(predictions, label='Decision Tree')
plt.legend(fontsize="20")
plt.title('Airline passengers by month')
plt.ylabel('Total passengers', fontsize="20")
plt.xlabel('Month', fontsize="20")
plt.show()

# %% [markdown]
# ## Детекция аномалий с помощью isolated forest

# %%
from sklearn.ensemble import IsolationForest

# %%
# аналогичным образом загружаем данные о пассажирах
pas = pd.read_csv('data/passengers.csv')
# неподходящий формат данных приводим к тому, с которым Pandas может работать
pas['Month'] = pd.to_datetime(passengers['Month'])
# также устанавливаем индекс и сортируем
pas
# Out:
#          Month  Passengers
# 0   1949-01-01         112
# 1   1949-02-01         118
# 2   1949-03-01         132
# 3   1949-04-01         129
# 4   1949-05-01         121
# ..         ...         ...
# 139 1960-08-01         606
# 140 1960-09-01         508
# 141 1960-10-01         461
# 142 1960-11-01         390
# 143 1960-12-01         432
#
# [144 rows x 2 columns]

# %%
model = IsolationForest(contamination=0.004)
model.fit(pas[['Passengers']])
# Out:
# IsolationForest(contamination=0.004)

# %%
pas['outliers'] = pd.Series(model.predict(pas[['Passengers']])).apply(lambda x: 'yes' if (x == -1) else 'no' )

# %%
pas.query('outliers=="yes"')
# Out:
#          Month  Passengers outliers
# 138 1960-07-01         622      yes

# %%
fig = px.scatter(pas.reset_index(), x='Month', y='Passengers', color='outliers')
fig.update_xaxes(
    rangeslider_visible=True,
)
fig.show()

# %% [markdown]
# ## Самостоятельная работа
#
# **Задание 1: Учет сезонности (больше лагов)**
# В нашем прошлом примере мы брали сдвиг всего на один месяц (`lag = 1`). В данных авиаперевозок есть очевидная годовая сезонность.
# Измените код так, чтобы модель смотрела на 12 предыдущих месяцев одновременно. Сформируйте выборку, обучите `RandomForest` с помощью функции `random_forest_forecast` и выведите метрики. Сравните, как изменились результаты.

# %%
cols = []

for i in range(12, 0, -1):
    cols.append(df.shift(i))

cols.append(df.shift(0))

agg = pd.concat(cols, axis=1)
agg.dropna(inplace=True)

list_for_forecast = agg.values

predictions = []
size = int(len(list_for_forecast) * 0.66)
train, test = list_for_forecast[0:size], list_for_forecast[size:]

history = [x for x in train]

for i in range(len(test)):
    testX, testy = test[i, :-1], test[i, -1]
    yhat = random_forest_forecast(history, testX)
    predictions.append(yhat)
    history.append(test[i])

print("Random Forest metrics: ")
print("RMSE:", np.sqrt(mean_squared_error(test[:, -1], predictions)))
print("MAPE:", mean_absolute_percentage_error(test[:, -1], predictions))
print("MAE:", mean_absolute_error(test[:, -1], predictions))
print("R2: ", r2_score(test[:, -1], predictions))
# Out:
# Random Forest metrics:
# RMSE: 33.63562941353179
# MAPE: 0.06312054870230589
# MAE: 26.815733333333334
# R2:  0.8059491806616207

# %% [markdown]
# Из-за того что в данных есть годовая сезонность, при увелечении сдвига (lag = 12), качество модели улучшается: снижаются ошибки (MAE (было 46.71,  стало 26.81), RMSE (было 55.54,  стало 33.54), MAPE (было 0.109,  стало 0.06)) и увеличивается коэффициент детерминации R2  (было 0.49,  стало 0.80).

# %% [markdown]
# **Задание 2: Сравнение деревьев с «глупым» бейзлайном (Naive Forecast)**
# Чтобы понимать, насколько вообще полезно применять Random Forest, нужен ориентир (baseline). Напишите простую «наивную» модель: в качестве прогноза на следующий шаг берется просто значение предыдущего шага ($\hat{y}_t = y_{t-1}$).
# Сравните $R^2$ и $MAE$ наивного прогноза с вашим лесом из Задания 1.

# %%
naive_predictions = []

for i in range(len(test)):
    yhat = test[i, -2]  # первый столбец = лаг 12
    naive_predictions.append(yhat)

print("Naive Forecast metrics:")
print("MAE:", mean_absolute_error(test[:, -1], naive_predictions))
print("R2:", r2_score(test[:, -1], naive_predictions))
# Out:
# Naive Forecast metrics:
# MAE: 40.977777777777774
# R2: 0.59033250438754

# %% [markdown]
# Mодель Random Forest, использующая 12 лагов, показывает оболее высокое качество (более низкий MAE (было 26.81,  стало 40.97) и более высокий R2 (было 0.80,  стало 0.59)). Использование более сложных моделей оправдано.

# %% [markdown]
# **Задание 3: Чувствительность алгоритма поиска аномалий**
# В конце практики мы использовали алгоритм `IsolationForest` для поиска аномалий с крайне низким параметром `contamination=0.004`.
# Измените этот параметр на `0.05` (поиск 5% самых аномальных периодов), обучите модель заново и отрисуйте график с новыми подсвеченными точками. Как поменялась картина, какие теперь месяцы считаются "нетипичными"?

# %%
pas = pd.read_csv('data/passengers.csv')
pas['Month'] = pd.to_datetime(pas['Month'])

# %%
model = IsolationForest(contamination=0.05)
model.fit(pas[['Passengers']])
# Out:
# IsolationForest(contamination=0.05)

# %%
pas['outliers'] = pd.Series(model.predict(pas[['Passengers']])).apply(lambda x: 'yes' if (x == -1) else 'no' )

# %%
pas.query('outliers=="yes"')
# Out:
#          Month  Passengers outliers
# 0   1949-01-01         112      yes
# 10  1949-11-01         104      yes
# 126 1959-07-01         548      yes
# 127 1959-08-01         559      yes
# 137 1960-06-01         535      yes
# 138 1960-07-01         622      yes
# 139 1960-08-01         606      yes
# 140 1960-09-01         508      yes

# %%
fig = px.scatter(pas, x='Month', y='Passengers', color='outliers')
fig.update_xaxes(rangeslider_visible=True)
fig.show()

# %% [markdown]
# При увеличении параметра contamination с 0.004 до 0.05 количество обнаруженных аномалий значительно увеличилось.
# Если ранее выделялись только самые экстремальные значения, то теперь алгоритм отмечает около 5% наблюдений как нетипичные.
# В основном аномалиями становятся летние месяцы с пиковыми значениями пассажиропотока, а также резкие отклонения от общего тренда, в данном случае ноябрь.
